# %%
import bike_networks
import osmnx as ox
import matplotlib.pyplot as plt
# %load_ext autoreload
# %autoreload 2

# %%
# %%capture
city_name = 'Tallahassee, Florida'
bnx = bike_networks.BikeNetworkMapper(city_name)
bnx.get_city(
    city_elements={'buildings':False,'green':False}
    )

# %%
fig,ax = bnx.plot_cycleways(
    signature=True,
    save_figure=True,
    extension=['png','pdf'])
