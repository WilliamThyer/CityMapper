# %%
import bike_networks
# %load_ext autoreload
# %autoreload 2

# %%
city_mapper = bike_networks.CityMapper()
city_mapper.load_city(
    city_name = 'Seattle, WA',
    city_limits = False,
    city_elements = {'roads':True,'cycleways':False}
)
# Out:
# Loading data for Seattle, WA. May take a few minutes.
# C:\Users\Jarvis\anaconda3\envs\ox\lib\site-packages\osmnx\geometries.py:805: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#   for merged_outer_linestring in list(merged_outer_linestrings):
# C:\Users\Jarvis\anaconda3\envs\ox\lib\site-packages\osmnx\geometries.py:805: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   for merged_outer_linestring in list(merged_outer_linestrings):

# %%
city_mapper.cycleways = city_mapper._get_cycleways()

# %%
fig = city_mapper.plot_city(
    road_cycleway_ratio_subtitle = False,
    # colors = {'city_area': None}
)

# %%
city_mapper.savefig(fig)
